# %% [markdown]
# CSYE7105 High Performance Parallel Machine Learning and AI
#
# Instructor: Dr. Handan Liu
#
# Dask 4: Diagnostics (local and distributed)

# %% [raw]
# local Diagnostics

# %%
import dask.array as da

# %%
from dask.diagnostics import ProgressBar
a = da.random.normal(size=(10000, 10000), chunks=(1000, 1000))
res = a.dot(a.T).mean(axis=0)

with ProgressBar():
    out = res.compute()
# Out:
# [                                        ] | 0% Completed | 102.38 us
# /opt/anaconda3/lib/python3.12/site-packages/dask/array/routines.py:331: PerformanceWarning: Increasing number of chunks by factor of 10
#   intermediate = blockwise(
# [########################################] | 100% Completed | 37.81 s

# %%
from dask.diagnostics import ResourceProfiler
rprof = ResourceProfiler(dt=0.5)

# %%
rprof

# %% [raw]
# Example:

# %%
import dask.array as da
from dask.diagnostics import Profiler, ResourceProfiler, CacheProfiler
a = da.random.random(size=(10000, 1000), chunks=(1000, 1000))
q, r = da.linalg.qr(a)
a2 = q.dot(r)

with Profiler() as prof, ResourceProfiler(dt=0.25) as rprof, CacheProfiler() as cprof:
        out = a2.compute()

# %%
prof.visualize()
# Out:
# figure(id='p1001', ...)

# %%
prof.results[0]
# Out:
# TaskData(key=('random_sample-051e435e957a9f09123230e5afbc130d', 9, 0), task=<Task ('random_sample-051e435e957a9f09123230e5afbc130d', 9, 0) _apply_random(...)>, start_time=192639.340075041, end_time=192639.34452225, worker_id=13052751872)

# %%
# rprof.results

# %%
# cprof.results

# %%
cprof.results[0]
# Out:
# CacheData(key=('random_sample-051e435e957a9f09123230e5afbc130d', 2, 0), task=<Task ('random_sample-051e435e957a9f09123230e5afbc130d', 2, 0) _apply_random(...)>, metric=1, cache_time=192639.350642875, free_time=192676.502375041)

# %% [raw]
# distributed diagnostics

# %%
from dask.distributed import Client
client = Client(processes=False)

from dask.distributed import get_task_stream 

a = da.random.random(size=(10000, 1000), chunks=(1000, 1000))
q, r = da.linalg.qr(a)
x = q.dot(r)

with get_task_stream(plot='save', filename="task-stream.html") as ts:
    x.compute()

client.profile(filename="dask-profile.html")

history = ts.data
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/distributed/node.py:188: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 57164 instead
#   warnings.warn(

# %%
client
# Out:
# <Client: 'inproc://10.110.17.70/83137/1' processes=1 threads=8, memory=8.00 GiB>
